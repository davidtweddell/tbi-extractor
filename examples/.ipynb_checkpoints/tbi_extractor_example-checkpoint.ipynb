# %% [markdown]
# # Example for using TBI Extractor

# %% [markdown]
# ### 1. Installation

# %%
# From the examples directory of tbiExtractor, install tbi-extractor
# %pip install ../.
# Out:
# Processing /home/margaret/Documents/research/tbiExtractor
# Requirement already satisfied: pyConTextNLP==0.6.2.0 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from tbi-extractor==0.2.0) (0.6.2.0)
# Requirement already satisfied: networkx==1.11 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from tbi-extractor==0.2.0) (1.11)
# Requirement already satisfied: numpy>=1.15.0 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from tbi-extractor==0.2.0) (1.19.1)
# Requirement already satisfied: pandas>=0.23.4 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from tbi-extractor==0.2.0) (1.1.1)
# Requirement already satisfied: spacy==2.0.12 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from tbi-extractor==0.2.0) (2.0.12)
# Requirement already satisfied: decorator>=3.4.0 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from networkx==1.11->tbi-extractor==0.2.0) (4.4.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from pandas>=0.23.4->tbi-extractor==0.2.0) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from pandas>=0.23.4->tbi-extractor==0.2.0) (2020.1)
# Requirement already satisfied: thinc<6.11.0,>=6.10.3 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from spacy==2.0.12->tbi-extractor==0.2.0) (6.10.3)
# Requirement already satisfied: regex==2017.4.5 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from spacy==2.0.12->tbi-extractor==0.2.0) (2017.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from spacy==2.0.12->tbi-extractor==0.2.0) (2.24.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from spacy==2.0.12->tbi-extractor==0.2.0) (0.9.6)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from spacy==2.0.12->tbi-extractor==0.2.0) (0.28.0)
# Requirement already satisfied: dill<0.3,>=0.2 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from spacy==2.0.12->tbi-extractor==0.2.0) (0.2.9)
# Requirement already satisfied: cymem<1.32,>=1.30 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from spacy==2.0.12->tbi-extractor==0.2.0) (1.31.2)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from spacy==2.0.12->tbi-extractor==0.2.0) (1.0.1)
# Requirement already satisfied: ujson>=1.35 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from spacy==2.0.12->tbi-extractor==0.2.0) (1.35)
# Requirement already satisfied: six>=1.5 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>=0.23.4->tbi-extractor==0.2.0) (1.15.0)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12->tbi-extractor==0.2.0) (0.9.0.1)
# Requirement already satisfied: msgpack-numpy<1.0.0,>=0.4.1 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12->tbi-extractor==0.2.0) (0.4.6.1)
# Processing /home/margaret/.cache/pip/wheels/4c/97/d2/6a717447f5f7aff7a2bf5528825b930a56466d312e8a011fba/wrapt-1.10.11-cp36-cp36m-linux_x86_64.whl
# Requirement already satisfied: msgpack<1.0.0,>=0.5.6 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12->tbi-extractor==0.2.0) (0.6.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12->tbi-extractor==0.2.0) (4.48.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12->tbi-extractor==0.2.0) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12->tbi-extractor==0.2.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12->tbi-extractor==0.2.0) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12->tbi-extractor==0.2.0) (2020.6.20)
# Requirement already satisfied: toolz>=0.8.0 in /home/margaret/anaconda/envs/gear/lib/python3.6/site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.11.0,>=6.10.3->spacy==2.0.12->tbi-extractor==0.2.0) (0.10.0)
# Building wheels for collected packages: tbi-extractor
#   Building wheel for tbi-extractor (setup.py) ... done
#   Created wheel for tbi-extractor: filename=tbi_extractor-0.2.0-py3-none-any.whl size=18356 sha256=4553a37cd1c84d84448e50611312bd1771b6de96461824866ea51b1bb80da1b7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7zbd2869/wheels/82/42/8d/376eeb829134c284bc5529390ca45112f8fc73bfd06f8e0245
# Successfully built tbi-extractor
# Installing collected packages: tbi-extractor, wrapt
#   Attempting uninstall: tbi-extractor
#     Found existing installation: tbi-extractor 0.2.0
#     Uninstalling tbi-extractor-0.2.0:
#       Successfully uninstalled tbi-extractor-0.2.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.12.1
#     Uninstalling wrapt-1.12.1:
#       Successfully uninstalled wrapt-1.12.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# astroid 2.4.2 requires wrapt~=1.11, but you'll have wrapt 1.10.11 which is incompatible.
# Successfully installed tbi-extractor-0.2.0 wrapt-1.10.11
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
import datetime
import pandas as pd
from tbi_extractor import run_algorithm

# %% [markdown]
# ### 2. tbiExtractor

# %%
# Gather input radiology report
report_file = 'report_two.txt'

# %%
# Show input
with open(report_file, 'r') as f:
    print(f.read())
# Out:
# Findings: There is no definite evidence of intracranial hemorrhage, mass effect, midline shift or abnormal extraaxial fluid collection. There are numerous subtle punctate hyperdense foci scattered throughout the brain. The ventricles do not appear enlarged out of proportion to the cerebral sulci. Gray-white differentiation subtle a slightly decreased. There is subtle diffuse swelling of the brain. There are multiple skull base fractures and extensive facial fractures which will be more completely detailed on the accompanying facial bone CT reconstructions. There are mildly displaced bilateral frontal bone fractures through the anterior table of the frontal sinuses and nondisplaced fracture of the greater wing of the right sphenoid.. There are extensive sinus fractures with near complete opacification of the maxillary sinuses, ethmoid air cells, and sphenoid sinuses. There are a few scattered left ethmoid air cell opacities. Right ethmoid air cells are relatively clear.. There are multiple foci of subcutaneous emphysema and large dermal defects scattered throughout the frontal scalp and the soft tissues of the face with soft tissue edema.
#
# Impression: 1. No definite acute intracranial hemorrhage is identified. Several punctate densities could possibly represent early signs of hemorrhage, perhaps the earliest visual evidence for axonal injuries, but overall not definitive. 2. Suspicion for diffuse subtle edema of the brain without loss of all gray-white differentiation. This is a nonspecific finding that may represent the earliest indication of diffuse edema from trauma or hypoxic ischemic encephalopathy, or some combination HIE and traumatic edema. 3. Complex facial and skull base fractures will be more completely detailed on the accompanying facial bones CT.

# %%
# Run tbiExtractor
df = run_algorithm.run(report_file)

# %%
# Show output
df
# Out:
#                    target_group modifier_group
# 0                      aneurysm         absent
# 1                        anoxic        present
# 2                       atrophy         absent
# 3                       cistern         normal
# 4                     contusion         absent
# 5                diffuse_axonal        present
# 6           epidural_hemorrhage         absent
# 7               facial_fracture        present
# 8                         fluid         absent
# 9    gray_white_differentiation       abnormal
# 10                   hemorrhage         absent
# 11                   herniation         absent
# 12                hydrocephalus         absent
# 13               hyperdensities        present
# 14                hypodensities         absent
# 15       intracranial_pathology        present
# 16   intraparenchymal_hemorrage         absent
# 17  intraventricular_hemorrhage         absent
# 18                     ischemia         absent
# 19                  mass_effect         absent
# 20              microhemorrhage         absent
# 21                midline_shift         absent
# 22               pneumocephalus         absent
# 23               skull_fracture        present
# 24      subarachnoid_hemorrhage         absent
# 25          subdural_hemorrhage         absent
# 26                     swelling        present

# %%
# Save output 
get_today = datetime.date.today()
outfile = 'tbi_extractor_example_output_' + str(get_today) + '.csv'
df.to_csv(outfile, index=False)

# %% [markdown]
# ### 3. Options: change the output format
#
# `save_target_phrases (bool)`:  If True, save the lexical target phrases identified in the report for the resulting annotation. Default = False.
#
# `save_modifier_phrases (bool)`: If True, save the lexical modifier phrases identified in the report for the resulting annotation. Default = False.

# %%
df = run_algorithm.run(report_file, 
                       save_target_phrases=True, 
                       save_modifier_phrases=True)
df
# Out:
#                                         target_phrase  \
# 0                                            aneurysm
# 1                                             hypoxic
# 2                                             atrophy
# 3                                             cistern
# 4                                           contusion
# 5                                              axonal
# 6                                 epidural_hemorrhage
# 7                      fractures and extensive facial
# 8                                               fluid
# 9                          gray-white differentiation
# 10  intracranial hemorrhage , intracranial hemorrh...
# 11                                         herniation
# 12                                      hydrocephalus
# 13                                    hyperdense foci
# 14                                      hypodensities
# 15                             intracranial_pathology
# 16                         intraparenchymal_hemorrage
# 17                        intraventricular_hemorrhage
# 18                                           ischemia
# 19                                        mass effect
# 20                                    microhemorrhage
# 21                                      midline shift
# 22                                     pneumocephalus
# 23                            frontal bone fractures
# 24                            subarachnoid_hemorrhage
# 25                                subdural_hemorrhage
# 26                                             edema
#
#                    target_group                     modifier_phrase  \
# 0                      aneurysm                             default
# 1                        anoxic                             diffuse
# 2                       atrophy                             default
# 3                       cistern                             default
# 4                     contusion                             default
# 5                diffuse_axonal                            evidence
# 6           epidural_hemorrhage                             default
# 7               facial_fracture                            multiple
# 8                         fluid                             default
# 9    gray_white_differentiation                             loss of
# 10                   hemorrhage                              absent
# 11                   herniation                             default
# 12                hydrocephalus                             default
# 13               hyperdensities                              subtle
# 14                hypodensities                             default
# 15       intracranial_pathology  default, is_intracranial_pathology
# 16   intraparenchymal_hemorrage                             default
# 17  intraventricular_hemorrhage                             default
# 18                     ischemia                             default
# 19                  mass_effect                      no evidence of
# 20              microhemorrhage                             default
# 21                midline_shift                      no evidence of
# 22               pneumocephalus                             default
# 23               skull_fracture                           displaced
# 24      subarachnoid_hemorrhage                             default
# 25          subdural_hemorrhage                             default
# 26                     swelling                             present
#
#    modifier_group
# 0          absent
# 1         present
# 2          absent
# 3          normal
# 4          absent
# 5         present
# 6          absent
# 7         present
# 8          absent
# 9        abnormal
# 10         absent
# 11         absent
# 12         absent
# 13        present
# 14         absent
# 15        present
# 16         absent
# 17         absent
# 18         absent
# 19         absent
# 20         absent
# 21         absent
# 22         absent
# 23        present
# 24         absent
# 25         absent
# 26        present

# %% [markdown]
# ### 4. Options: limit the lexical targets investigated
#
# > Can only set to include or exclude lexical target options to limit the search. Defaults to standard target list.
#
# `include_targets (list)`: A subset of the available lexical targets options to include. Default: None, resulting in standard target list output.
#
# `exclude_targets (list)`: A subset of the available lexical targets options to exclude. Default: None, resulting in standard target list output.

# %%
df = run_algorithm.run(report_file, 
                       include_targets=['subdural_hemorrhage', 'epidural_hemorrhage'])
df
# Out:
#           target_group modifier_group
# 0  epidural_hemorrhage         absent
# 1  subdural_hemorrhage         absent

# %%
df = run_algorithm.run(report_file, 
                       exclude_targets=['atrophy'])
df
# Out:
#                    target_group modifier_group
# 0                      aneurysm         absent
# 1                        anoxic        present
# 2                       cistern         normal
# 3                     contusion         absent
# 4                diffuse_axonal        present
# 5           epidural_hemorrhage         absent
# 6               facial_fracture        present
# 7                         fluid         absent
# 8    gray_white_differentiation       abnormal
# 9                    hemorrhage         absent
# 10                   herniation         absent
# 11                hydrocephalus         absent
# 12               hyperdensities        present
# 13                hypodensities         absent
# 14       intracranial_pathology        present
# 15   intraparenchymal_hemorrage         absent
# 16  intraventricular_hemorrhage         absent
# 17                     ischemia         absent
# 18                  mass_effect         absent
# 19              microhemorrhage         absent
# 20                midline_shift         absent
# 21               pneumocephalus         absent
# 22               skull_fracture        present
# 23      subarachnoid_hemorrhage         absent
# 24          subdural_hemorrhage         absent
# 25                     swelling        present
